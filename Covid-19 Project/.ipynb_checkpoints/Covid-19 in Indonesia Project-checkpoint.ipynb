# %% [markdown]
# # Covid-19 in Indonesia

# %% [markdown]
# Saya mencoba melakukan analisis ringan terkait covid-19 di Indonesia, untuk sumber data saya mengambilnya dari https://data.humdata.org/dataset/indonesia-covid-19-cases-recoveries-and-deaths-per-province. Data yang saya gunakan merupakan data per tanggal 23 Juni 2020

# %% [markdown]
# # Importing the required libraries

# %%
#import library yang diperlukan
import pandas as pd

# %% [markdown]
# # Data Preparation

# %%
# memanggil data yang digunakan untuk analisis
covid = pd.read_csv("E:/Proyek/Portofolio/Proyek Covid/Indonesia/Case by Provinces - IDN-COVID19 - Sheet2.csv")

# %%
# melihat beberapa data
covid.head()
# Out:
#                 Type Features Type  ID-number  Province_code   Province_name  \
# 0  FeatureCollection       Feature          1             11            Aceh
# 1  FeatureCollection       Feature          2             12  Sumatera Utara
# 2  FeatureCollection       Feature          3             13  Sumatera Barat
# 3  FeatureCollection       Feature          4             14            Riau
# 4  FeatureCollection       Feature          5             15           Jambi
#
#    Confirmed_cases  Recovered_cases  Death_cases Features Geometry Type  \
# 0               49               20            2                  Point
# 1             1232              266           76                  Point
# 2              712              525           30                  Point
# 3              193              117            9                  Point
# 4              114               66            9                  Point
#
#           Features Geometry Coordinates
# 0   96.90952274800009,4.225081892000048
# 1   99.05788784900005,2.184779215000049
# 2  100.46680503000005,-0.85191434799998
# 3  101.81289195400007,0.510525849000032
# 4                    103.59932,-1.61775

# %%
# mengecek missing value
covid.isnull().sum()
# Out:
# Type                             0
# Features Type                    0
# ID-number                        0
# Province_code                    0
# Province_name                    0
# Confirmed_cases                  0
# Recovered_cases                  0
# Death_cases                      0
# Features Geometry Type           0
# Features Geometry Coordinates    0
# dtype: int64

# %% [markdown]
# Dapat dilihat diatas bahwa data yang digunakan merupakan data yang baik/bagus

# %%
# mengambil kolom yang akan kita gunakan 
covid = covid[['Province_name','Confirmed_cases','Recovered_cases','Death_cases']]

# %%
covid.head()
# Out:
#     Province_name  Confirmed_cases  Recovered_cases  Death_cases
# 0            Aceh               49               20            2
# 1  Sumatera Utara             1232              266           76
# 2  Sumatera Barat              712              525           30
# 3            Riau              193              117            9
# 4           Jambi              114               66            9

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Analisis Data Covid-19 di Indonesia

# %%
#membuat variabel baru bernama total_cases yang merupakan jumlah kasus covid-19 terkonfirmasi
total_cases = covid['Confirmed_cases'].sum()
print('Total number of confirmed COVID 2019 cases across Indonesia till date (23rd June, 2020):', total_cases)
# Out:
# Total number of confirmed COVID 2019 cases across Indonesia till date (23rd June, 2020): 48120

# %%
#menghitung jumlah kasus sembuh, meninggal, dan aktif
total_recovered = covid['Recovered_cases'].sum()
print("Total people who were recovered as of 23rd June, 2020 are: ", total_recovered)
total_cases = covid['Confirmed_cases'].sum()
print("Total people who were detected COVID19 as of 23rd June, 2020 are: ", total_cases)
total_death = covid['Death_cases'].sum()
print("Total people who died due to COVID19 as of 23rd June, 2020 are: ",total_death)
total_active = total_cases-total_recovered-total_death
print("Total active COVID19 cases as of 23rd June, 2020 are: ",total_active)
# Out:
# Total people who were recovered as of 23rd June, 2020 are:  19370
# Total people who were detected COVID19 as of 23rd June, 2020 are:  48120
# Total people who died due to COVID19 as of 23rd June, 2020 are:  2547
# Total active COVID19 cases as of 23rd June, 2020 are:  26203

# %%
#JUmlah kasus aktif adalah Jumlah seluruh Kasus - (Jumlah Kasus Meninggal + Jumlah Kasus Sembuh)
covid['Total Active'] = covid['Confirmed_cases'] - (covid['Death_cases'] + covid['Recovered_cases'])
total_active = covid['Total Active'].sum()
print('Total number of active COVID 2019 cases across Indonesia:', total_active)
Tot_Cases = covid.groupby('Province_name')['Total Active'].sum().sort_values(ascending=False).to_frame()
Tot_Cases.style.background_gradient(cmap='Reds')
# Out:
# Total number of active COVID 2019 cases across Indonesia: 26203
# <style  type="text/css" >
#     #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row1_col0 {
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row2_col0 {
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row3_col0 {
#             background-color:  #fca588;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row4_col0 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row5_col0 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row6_col0 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row7_col0 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row8_col0 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row9_col0 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row10_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row11_col0 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row12_col0 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row13_col0 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row14_col0 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row15_col0 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row16_col0 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row17_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row18_col0 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row19_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row20_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row21_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row22_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row23_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row24_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row25_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row26_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row27_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row28_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row29_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row30_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row31_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row32_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row33_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row34_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Active</th>    </tr>    <tr>        <th class="index_name level0" >Province_name</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row0" class="row_heading level0 row0" >Jawa Timur</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row0_col0" class="data row0 col0" >6459</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row1" class="row_heading level0 row1" >DKI Jakarta</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row1_col0" class="data row1 col0" >4428</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row2" class="row_heading level0 row2" >Sulawesi Selatan</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row2_col0" class="data row2 col0" >2553</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row3" class="row_heading level0 row3" >Kalimantan Selatan</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row3_col0" class="data row3 col0" >2085</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row4" class="row_heading level0 row4" >Jawa Tengah</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row4_col0" class="data row4 col0" >1598</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row5" class="row_heading level0 row5" >Jawa Barat</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row5_col0" class="data row5 col0" >1413</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row6" class="row_heading level0 row6" >Papua</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row6_col0" class="data row6 col0" >1191</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row7" class="row_heading level0 row7" >Sumatera Selatan</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row7_col0" class="data row7 col0" >967</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row8" class="row_heading level0 row8" >Sumatera Utara</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row8_col0" class="data row8 col0" >890</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row9" class="row_heading level0 row9" >Banten</th>
#                         <td id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8row9_col0" class="data row9 col0" >711</td>
#             </tr>
#             <tr>
#                         <th id="T_b67d5a78_bab9_11ea_9758_b0fc3678c7c8level0_row10" class="row_heading level0 row10" >Sulawesi Utara

# %%
import numpy as np
state_cases = covid.groupby('Province_name')['Confirmed_cases','Death_cases','Recovered_cases'].max().reset_index()

#state_cases = state_cases.astype({'Deaths': 'int'})
state_cases['Active'] = state_cases['Confirmed_cases'] - (state_cases['Death_cases']+state_cases['Recovered_cases'])
state_cases["Death Rate (per 100)"] = np.round(100*state_cases["Death_cases"]/state_cases["Confirmed_cases"],2)
state_cases["Recovered Rate (per 100)"] = np.round(100*state_cases["Recovered_cases"]/state_cases["Confirmed_cases"],2)
state_cases.sort_values('Confirmed_cases', ascending= False).fillna(0).style.background_gradient(cmap='Blues',subset=["Confirmed_cases"])\
                        .background_gradient(cmap='Blues',subset=["Death_cases"])\
                        .background_gradient(cmap='Blues',subset=["Recovered_cases"])\
                        .background_gradient(cmap='Blues',subset=["Active"])\
                        .background_gradient(cmap='Blues',subset=["Death Rate (per 100)"])\
                        .background_gradient(cmap='Blues',subset=["Recovered Rate (per 100)"])
# Out:
# C:\Users\Harry\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# <style  type="text/css" >
#     #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col2 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col4 {
#             background-color:  #3282be;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col5 {
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row0_col6 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col1 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col3 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col5 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row1_col6 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col1 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col2 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col3 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col4 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col5 {
#             background-color:  #8fc2de;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row2_col6 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col2 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col3 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col4 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col5 {
#             background-color:  #2979b9;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row3_col6 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col1 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col2 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col3 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col4 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col5 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row4_col6 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col1 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col2 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col3 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col4 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col5 {
#             background-color:  #1e6db2;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row5_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col2 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col3 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col4 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col5 {
#             background-color:  #7fb9da;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row6_col6 {
#             background-color:  #91c3de;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col1 {
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col2 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col3 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col4 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row7_col6 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col1 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col2 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col3 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col4 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col5 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row8_col6 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col1 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col2 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col3 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col4 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col5 {
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }    #T_b6c19fc2_bab9_11ea_ab85_b0fc3678c7c8row9_col6 {
#             background-color:  #e7f1fa;
#             color:  #000000;

# %% [markdown]
# # Conclusion(Kesimpulan)

# %% [markdown]
# # Tabel Pertama
# Dari dua Tabel yang didapat kita dapat melihat pada tabel pertama bahwa Jumlah kasus aktif tertinggi terdapat di Provinsi Jawa Timur, diidentifikasikan dengan warna merah gelap dan terendah terdapat pada Provinsi Sulawesi Barat.

# %% [markdown]
# # Tabel Kedua
# Pada tabel kedua kita bisa melihat bahwa jumlah kasus covid-19 terbanyak terdapat di Provinsi DKI Jakarta diikuti dengan Provindi Jawa Timur dan Sulawesi Selatan.
#
# Jumlah Kasus aktif tertinggi terdapat pada Provinsi Jawa Timur
#
# Jumlah Kematian tertinggi terdapat pada Provinsi Jawa Timur
#
# Jumlah Kesembuhan tertinggi terdapat pada Provinsi DKI Jakarta
#
# Serta Proporsi Kasus Aktif, Sembuh serta Meninggal di Seluruh Provinsi Indonesia

# %% [markdown]
# # Visualization

# %%
#Import Library
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import file dari website yang sama, dengan nama file Daily-Update IDN-COVID19
covid_daily = pd.read_csv("E:/Proyek/Portofolio/Proyek Covid/Indonesia/Daily-Update IDN-COVID19 - Sheet5.csv")

# %%
#Melihat Beberapa Data
covid_daily.head()
# Out:
#        Date  Cumulative_cases  Recovered_cases  Total_death  \
# 0  3/2/2020                 2              NaN          NaN
# 1  3/3/2020                 2              NaN          NaN
# 2  3/4/2020                 2              NaN          NaN
# 3  3/5/2020                 2              NaN          NaN
# 4  3/6/2020                 4              NaN          NaN
#
#    Patient_under_treatment  New_case_per_day  Recovered-cases_perDay  \
# 0                        2                 2                     NaN
# 1                        2                 2                     NaN
# 2                        2                 2                     NaN
# 3                        2                 2                     NaN
# 4                        4                 2                     NaN
#
#    Death_cases_perDay  Treatment_cases_perDay
# 0                 NaN                       2
# 1                 NaN                       2
# 2                 NaN                       2
# 3                 NaN                       2
# 4                 NaN                       2

# %%
#Mengecek missing value
covid_daily.isnull().sum()
# Out:
# Date                       0
# Cumulative_cases           0
# Recovered_cases            8
# Total_death                9
# Patient_under_treatment    0
# New_case_per_day           0
# Recovered-cases_perDay     8
# Death_cases_perDay         9
# Treatment_cases_perDay     0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
covid_daily.fillna(0)
# Out:
#           Date  Cumulative_cases  Recovered_cases  Total_death  \
# 0     3/2/2020                 2              0.0          0.0
# 1     3/3/2020                 2              0.0          0.0
# 2     3/4/2020                 2              0.0          0.0
# 3     3/5/2020                 2              0.0          0.0
# 4     3/6/2020                 4              0.0          0.0
# ..         ...               ...              ...          ...
# 109  6/19/2020             43803          17349.0       2373.0
# 110  6/20/2020             45029          17883.0       2429.0
# 111  6/21/2020             45891          18404.0       2465.0
# 112  6/22/2020             46845          18735.0       2500.0
# 113  6/23/2020             47896          19241.0       2535.0
#
#      Patient_under_treatment  New_case_per_day  Recovered-cases_perDay  \
# 0                          2                 2                     0.0
# 1                          2                 2                     0.0
# 2                          2                 2                     0.0
# 3                          2                 2                     0.0
# 4                          4                 2                     0.0
# ..                       ...               ...                     ...
# 109                    24081              1041                   551.0
# 110                    24717              1226                   534.0
# 111                    25022               862                   521.0
# 112                    25610               954                   331.0
# 113                    26120              1051                   506.0
#
#      Death_cases_perDay  Treatment_cases_perDay
# 0                   0.0                       2
# 1                   0.0                       2
# 2                   0.0                       2
# 3                   0.0                       2
# 4                   0.0                       2
# ..                  ...                     ...
# 109                34.0                     456
# 110                56.0                     636
# 111                36.0                     305
# 112                35.0                     588
# 113                35.0                     510
#
# [114 rows x 9 columns]

# %%
covid_daily_cc = covid_daily[["Date","Cumulative_cases","Recovered_cases","Total_death", "Patient_under_treatment"]]
covid_daily_cc = covid_daily_cc.set_index('Date')
covid_daily_cc.head()
# Out:
#           Cumulative_cases  Recovered_cases  Total_death  \
# Date
# 3/2/2020                 2              NaN          NaN
# 3/3/2020                 2              NaN          NaN
# 3/4/2020                 2              NaN          NaN
# 3/5/2020                 2              NaN          NaN
# 3/6/2020                 4              NaN          NaN
#
#           Patient_under_treatment
# Date
# 3/2/2020                        2
# 3/3/2020                        2
# 3/4/2020                        2
# 3/5/2020                        2
# 3/6/2020                        4

# %%
covid_daily_cc.plot(kind='line', figsize=(14,8))

# %%
covid_cases_pd = covid_daily[["Date","New_case_per_day","Recovered-cases_perDay","Death_cases_perDay","Treatment_cases_perDay"]]
covid_cases_pd = covid_cases_pd.set_index('Date')
covid_cases_pd.plot(kind='line', figsize=(14,8))
